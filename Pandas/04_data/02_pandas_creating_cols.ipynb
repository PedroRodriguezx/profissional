# %%
import pandas as pd

# %%
df = pd.read_csv ('./data/users.csv')

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age
# 0      Glenda.Pyle@gmail.com  firefighter  25.0
# 1     Hollie.Allys@gmail.com       worker  26.0
# 2     Grier.Henrie@gmail.com       doctor  23.0
# 3  Kittie.Strephon@gmail.com       worker  45.0
# 4    Kassey.Prober@gmail.com       worker  45.0

# %%
df ['process'] = 'jupyter_analyses'

# %%
df ['age_plus'] = df['age'] + 10

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age           process  age_plus
# 0      Glenda.Pyle@gmail.com  firefighter  25.0  jupyter_analyses      35.0
# 1     Hollie.Allys@gmail.com       worker  26.0  jupyter_analyses      36.0
# 2     Grier.Henrie@gmail.com       doctor  23.0  jupyter_analyses      33.0
# 3  Kittie.Strephon@gmail.com       worker  45.0  jupyter_analyses      55.0
# 4    Kassey.Prober@gmail.com       worker  45.0  jupyter_analyses      55.0

# %%
df ['fullname'] = df['firstname'] + ' ' + df['lastname']

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age           process  age_plus  \
# 0      Glenda.Pyle@gmail.com  firefighter  25.0  jupyter_analyses      35.0
# 1     Hollie.Allys@gmail.com       worker  26.0  jupyter_analyses      36.0
# 2     Grier.Henrie@gmail.com       doctor  23.0  jupyter_analyses      33.0
# 3  Kittie.Strephon@gmail.com       worker  45.0  jupyter_analyses      55.0
# 4    Kassey.Prober@gmail.com       worker  45.0  jupyter_analyses      55.0
#
#           fullname
# 0      Glenda Pyle
# 1     Hollie Allys
# 2     Grier Henrie
# 3  Kittie Strephon
# 4    Kassey Prober

# %%
from datetime import datetime as dt

# %%
df['created_datetime'] = dt.now()

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age           process  age_plus  \
# 0      Glenda.Pyle@gmail.com  firefighter  25.0  jupyter_analyses      35.0
# 1     Hollie.Allys@gmail.com       worker  26.0  jupyter_analyses      36.0
# 2     Grier.Henrie@gmail.com       doctor  23.0  jupyter_analyses      33.0
# 3  Kittie.Strephon@gmail.com       worker  45.0  jupyter_analyses      55.0
# 4    Kassey.Prober@gmail.com       worker  45.0  jupyter_analyses      55.0
#
#           fullname           created_datetime
# 0      Glenda Pyle 2023-12-18 19:46:51.046842
# 1     Hollie Allys 2023-12-18 19:46:51.046842
# 2     Grier Henrie 2023-12-18 19:46:51.046842
# 3  Kittie Strephon 2023-12-18 19:46:51.046842
# 4    Kassey Prober 2023-12-18 19:46:51.046842

# %%
df['created_date'] = dt.today().strftime('%y-%m-%d')

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age           process  age_plus  \
# 0      Glenda.Pyle@gmail.com  firefighter  25.0  jupyter_analyses      35.0
# 1     Hollie.Allys@gmail.com       worker  26.0  jupyter_analyses      36.0
# 2     Grier.Henrie@gmail.com       doctor  23.0  jupyter_analyses      33.0
# 3  Kittie.Strephon@gmail.com       worker  45.0  jupyter_analyses      55.0
# 4    Kassey.Prober@gmail.com       worker  45.0  jupyter_analyses      55.0
#
#           fullname           created_datetime created_date
# 0      Glenda Pyle 2023-12-18 19:46:51.046842     23-12-18
# 1     Hollie Allys 2023-12-18 19:46:51.046842     23-12-18
# 2     Grier Henrie 2023-12-18 19:46:51.046842     23-12-18
# 3  Kittie Strephon 2023-12-18 19:46:51.046842     23-12-18
# 4    Kassey Prober 2023-12-18 19:46:51.046842     23-12-18
