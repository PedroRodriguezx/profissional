# %%
import pandas as pd

# %%
df = pd.read_csv ('./data/users.csv')

# %%
df.head()
# Out:
#     id firstname  lastname                        email  \
# 0  100    Glenda      Pyle      Glenda.Pyle@yopmail.com
# 1  101    Hollie     Allys     Hollie.Allys@yopmail.com
# 2  102     Grier    Henrie     Grier.Henrie@yopmail.com
# 3  103    Kittie  Strephon  Kittie.Strephon@yopmail.com
# 4  104    Kassey    Prober    Kassey.Prober@yopmail.com
#
#                       email2   profession   age
# 0      Glenda.Pyle@gmail.com  firefighter  25.0
# 1     Hollie.Allys@gmail.com       worker  26.0
# 2     Grier.Henrie@gmail.com       doctor  23.0
# 3  Kittie.Strephon@gmail.com       worker  45.0
# 4    Kassey.Prober@gmail.com       worker  45.0

# %%
df_cols = df[['firstname', 'email', 'profession']]

# %%
df_cols
# Out:
#      firstname                           email      profession
# 0       Glenda         Glenda.Pyle@yopmail.com     firefighter
# 1       Hollie        Hollie.Allys@yopmail.com          worker
# 2        Grier        Grier.Henrie@yopmail.com          doctor
# 3       Kittie     Kittie.Strephon@yopmail.com          worker
# 4       Kassey       Kassey.Prober@yopmail.com          worker
# 5         Lusa        Lusa.Kolnick@yopmail.com     firefighter
# 6   Fredericka  Fredericka.Florina@yopmail.com     firefighter
# 7    Constance    Constance.Georgy@yopmail.com          doctor
# 8        Maria       Averyl.Concha@yopmail.com  police officer
# 9         Lily           Lily.Uird@yopmail.com     firefighter
# 10      Malina      Malina.Huggins@yopmail.com          worker
# 11      Dorthy       Dorthy.Nisbet@yopmail.com          doctor
# 12      Tiffie      Tiffie.Joachim@yopmail.com          doctor
# 13      Agathe     Agathe.Adrienne@yopmail.com       developer
# ...

# %%
df_30_plus = df[df['age'] > 30 ]

# %%
df_30_plus
# Out:
#      id   firstname  lastname                           email  \
# 3   103      Kittie  Strephon     Kittie.Strephon@yopmail.com
# 4   104      Kassey    Prober       Kassey.Prober@yopmail.com
# 6   106  Fredericka   Florina  Fredericka.Florina@yopmail.com
# 8   108       Maria    Concha       Averyl.Concha@yopmail.com
# 9   109        Lily      Uird           Lily.Uird@yopmail.com
# 12  112      Tiffie   Joachim      Tiffie.Joachim@yopmail.com
# 13  113      Agathe  Adrienne     Agathe.Adrienne@yopmail.com
#
#                           email2      profession   age
# 3      Kittie.Strephon@gmail.com          worker  45.0
# 4        Kassey.Prober@gmail.com          worker  45.0
# 6   Fredericka.Florina@gmail.com     firefighter  43.0
# 8       Averyl.Concha@uol.com.br  police officer  41.0
# 9            Lily.Uird@gmail.com     firefighter  46.0
# 12      Tiffie.Joachim@gmail.com          doctor  33.0
# 13     Agathe.Adrienne@gmail.com       developer  32.0

# %%
df_30_plus_firefighter = df[(df['age'] > 30) & (df['profession'] == 'firefighter') ]

# %%
df_30_plus_firefighter
# Out:
#     id   firstname lastname                           email  \
# 6  106  Fredericka  Florina  Fredericka.Florina@yopmail.com
# 9  109        Lily     Uird           Lily.Uird@yopmail.com
#
#                          email2   profession   age
# 6  Fredericka.Florina@gmail.com  firefighter  43.0
# 9           Lily.Uird@gmail.com  firefighter  46.0

# %%
df_email_contains = (
    df[(df['email'].str.contains('.com.br')) 
    |
    (df['email2'].str.contains('.com.br')) 
    ]
)

# %%
df_email_contains
# Out:
#      id firstname lastname                      email  \
# 8   108     Maria   Concha  Averyl.Concha@yopmail.com
# 14  114      Joao    Silva      joao.silva@bol.com.br
#
#                        email2      profession   age
# 8    Averyl.Concha@uol.com.br  police officer  41.0
# 14  joao.silva.02@zipmail.com       developer  19.0
